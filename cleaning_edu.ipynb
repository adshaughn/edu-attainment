# %%
import pandas as pd

# %%
#bring in US data

usa_df = pd.read_csv("original_data/us_edu_sex.csv")

# %%
usa_df.head()
# Out:
#   Table with row headers in column A and column headers in rows 5 through 6  \
# 0                                          All Races
# 1                                                NaN
# 2                                               Male
# 3                                 .18 years and over
# 4                                   ..18 to 24 years
#
#                Unnamed: 1 Unnamed: 2       Unnamed: 3       Unnamed: 4  \
# 0  Educational Attainment        NaN              NaN              NaN
# 1                   Total       None  1st - 4th grade  5th - 6th grade
# 2                     NaN        NaN              NaN              NaN
# 3                 122,151        378              717            1,435
# 4                  14,634         27               16               45
#
#         Unnamed: 5 Unnamed: 6  Unnamed: 7   Unnamed: 8            Unnamed: 9  \
# 0              NaN        NaN         NaN          NaN                   NaN
# ...

# %%
usa_df.transpose()
# Out:
#                                                                         0   \
# Table with row headers in column A and column h...               All Races
# Unnamed: 1                                          Educational Attainment
# Unnamed: 2                                                             NaN
# Unnamed: 3                                                             NaN
# Unnamed: 4                                                             NaN
# Unnamed: 5                                                             NaN
# Unnamed: 6                                                             NaN
# Unnamed: 7                                                             NaN
# Unnamed: 8                                                             NaN
# Unnamed: 9                                                             NaN
# Unnamed: 10                                                            NaN
# ...

# %%
usa_df = usa_df.transpose()

# %%
usa_df.head()
# Out:
#                                                                         0   \
# Table with row headers in column A and column h...               All Races
# Unnamed: 1                                          Educational Attainment
# Unnamed: 2                                                             NaN
# Unnamed: 3                                                             NaN
# Unnamed: 4                                                             NaN
#
#                                                                  1     2   \
# Table with row headers in column A and column h...              NaN  Male
# Unnamed: 1                                                    Total   NaN
# Unnamed: 2                                                     None   NaN
# Unnamed: 3                                          1st - 4th grade   NaN
# Unnamed: 4                                          5th - 6th grade   NaN
#
# ...
